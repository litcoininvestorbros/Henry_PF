# %% [markdown]
# # EDA METADATA GOOGLE

# %% [markdown]
# Imortamos la librerias necesarias.

# %%
import pandas as pd
import json

# %%
df1 = pd.read_json('C:/Users/Jonathan y Johana/Desktop/DATA/Google Maps/metadata-sitios/1.json', lines=True)

# %%
df1
# Out:
#                                    name  \
# 0                       Porter Pharmacy
# 1                          City Textile
# 2                          San Soo Dang
# 3                          Nova Fabrics
# 4                      Nobel Textile Co
# ...                                 ...
# 274996                     Maven Realty
# 274997               Stone Castle Fence
# 274998  Health Insurance Solutions Team
# 274999          Bernard Building Center
# 275000    HMR Motor Works and Auto Care
#
#                                                   address  \
# 0       Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1       City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2       San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3       Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4       Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# ...                                                   ...
# 274996  Maven Realty, 2180 McMillan Ave #71672, North ...
# ...

# %%
duplicados_gmap_id = df1[df1.duplicated('gmap_id')]

# Si deseas contar el número de duplicados, puedes usar la función len()
num_duplicados_gmap_id = len(duplicados_gmap_id)

# Imprimir los duplicados encontrados
print("Número de duplicados en la columna 'gmap_id':", num_duplicados_gmap_id)
print("Duplicados en la columna 'gmap_id':")
print(duplicados_gmap_id)
# Out:
# Número de duplicados en la columna 'gmap_id': 26573
# Duplicados en la columna 'gmap_id':
#                                                    name  \
# 26573                                   Porter Pharmacy
# 26574                                      City Textile
# 26575                                      San Soo Dang
# 26576                                      Nova Fabrics
# 26577                                  Nobel Textile Co
# ...                                                 ...
# 53141              Sherwin-Williams Floorcovering Store
# 53142                                   Sauna Warehouse
# 53143                                      Sport Chalet
# 53144                                    Smoke Zone SLC
# 53145  Salt Lake City cab taxi services/transportation.
#
#                                                  address  \
# 26573  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 26574  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# ...

# %%
# Funsion para hacer un explode en aquellas columnas que contienen listas de datos.
def explode_columna(df: pd.DataFrame, columna_a_explodar: str) -> pd.DataFrame:
    return df.explode(columna_a_explodar)
# Funsion para filtrar la categoria que vayamos a usar de acuerdo al tipo de estudio de eleccion.
def filtrar_por_categoria(df: pd.DataFrame, columna_a_filtrar: str, keyword: str) -> pd.DataFrame:
    df = df.dropna(subset=[columna_a_filtrar])
    return df[df[columna_a_filtrar].str.contains(keyword, case=False)]
# Funsion para tratamiento de datos duplicados por columna.
def eliminar_duplicados(df: pd.DataFrame, columna_a_verificar: str) -> pd.DataFrame:
    return df.drop_duplicates(subset=[columna_a_verificar], keep='first')

# %%
df_nuevo = explode_columna(df1,'category')

# %%
df_nuevo = filtrar_por_categoria(df_nuevo,'category','restaurant')

# %%
df_nuevo
# Out:
# <bound method DataFrame.info of                                        name  \
# 0                              San Soo Dang
# 1                              Vons Chicken
# 2     Sweet Rewards Gluten Free Bakery, LLC
# 3                           Vivi Bubble Tea
# 4                                 Hale Pops
# ...                                     ...
# 8595      ON THE RIVER SPORTS BAR AND GRILL
# 8596       E-Z Access Restarunt And Carwash
# 8597                       Palermo’s Market
# 8598                      Shin-Sen-Gumi 2GO
# 8599                           Toraji Ramen
#
#                                                 address  \
# 0     San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 1     Vons Chicken, 12740 La Mirada Blvd, La Mirada,...
# 2     Sweet Rewards Gluten Free Bakery, LLC, 85 NE D...
# 3     Vivi Bubble Tea, 701 S 5th St, Philadelphia, P...
# 4      Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762
# ...                                                 ...
# ...

# %%
df_nuevo.shape[0]
# Out:
# 16466

# %%
df_nuevo = eliminar_duplicados(df_nuevo,'name')

# %%
df_nuevo.shape[0]
# Out:
# 8600

# %%
df_nuevo.reset_index(drop=True, inplace=True)

# %%
df_nuevo
# Out:
#                                        name  \
# 0                              San Soo Dang
# 1                              Vons Chicken
# 2     Sweet Rewards Gluten Free Bakery, LLC
# 3                           Vivi Bubble Tea
# 4                                 Hale Pops
# ...                                     ...
# 8595      ON THE RIVER SPORTS BAR AND GRILL
# 8596       E-Z Access Restarunt And Carwash
# 8597                       Palermo’s Market
# 8598                      Shin-Sen-Gumi 2GO
# 8599                           Toraji Ramen
#
#                                                 address  \
# 0     San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 1     Vons Chicken, 12740 La Mirada Blvd, La Mirada,...
# 2     Sweet Rewards Gluten Free Bakery, LLC, 85 NE D...
# 3     Vivi Bubble Tea, 701 S 5th St, Philadelphia, P...
# 4      Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762
# ...                                                 ...
# ...
